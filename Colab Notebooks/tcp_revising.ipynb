# %%
from google.colab import drive
import os
import pandas as pd
import numpy as np
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import ast

def count_keywords(title, keyword_df, month, loan_count):
    title_lower = title.lower()

    for index, row in keyword_df.iterrows():
        # 문자열 형태의 키워드 리스트를 실제 리스트로 변환
        keyword_list = ast.literal_eval(row['키워드'])
        print('DEBUG'+file_path+":   processing data     :"+row['키워드'])
        for keyword in keyword_list:
            # 정규 표현식을 사용하여 단어 경계를 확인
            if re.search(r'\b' + re.escape(keyword.lower()) + r'\b', title_lower):
                # 해당 키워드의 연도별 빈도수에 대출 횟수를 더함
                keyword_df.at[index, month] += loan_count
                break  # 한 키워드가 발견되면 나머지 키워드는 검사하지 않음

# %%
def processing_stackcount(file_path, keyword_df, year):
    temp_df = pd.read_excel(file_path)
    # 각 제목과 대출 횟수에 대해 count_keywords 함수 적용
    for _, row in temp_df.iterrows():
        print('DEBUG'+file_path+":   processing data"+row['서명'])
        count_keywords(row['서명'], keyword_df, year, row['대출건수'])

# %%
years = range(2018, 2024)  # 연도 범위
months = range(1, 11)  # 월 범위

keyword_df = pd.read_excel("/content/drive/MyDrive/대출 데이터 모음/연도별 키워드 처리/spring 키워드에 대한 분석.xlsx")

# 각 연도별 데이터 폴더를 순회
base_path = '/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/'
for year in years:
    year_folder_path = os.path.join(base_path, str(year))
    if os.path.exists(year_folder_path):
        for month in months:
            file_name = f"{year}_{month}_keyword_processed.xlsx"
            file_path = os.path.join(year_folder_path, file_name)
            if os.path.exists(file_path):
                # filtering_datarow(file_path, year, month)
                print('DEBUG'+file_path)
                processing_stackcount(file_path, keyword_df, year)

            else:
                print(f"File not found: {file_path}")
    else:
        print(f"Year folder not found: {year_folder_path}")

keyword_df.to_excel("/content/drive/MyDrive/대출 데이터 모음/연도별 키워드 처리/spring 키워드에 대한 분석_결과.xlsx")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(딥러닝을 위한) 파이토치 입문 =지도, 비지도, 준지도, 전이, 메타 학습까지 /Pytorch for deeplearning
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataIT 용어 도감 :비즈니스에서 사용할 수 있는 엄선 키워드 256
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data인공지능 세계에서 살아남기
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data바로 쓰는 파이썬
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data알고리즘이 당신에게 이것을 추천합니다 :부지런한 알고리즘이 안내하는 새로운 세상
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(코딩책과 함께 보는) 소프트웨어 개념 사전
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data토비의 스프링 3.1
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data역사 속의 소프트웨어 오류 :부실한 소프트웨어가 초래한 위험천만한 사건 사고들
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data칼퇴하는 일잘러의 업무 스킬, 파이썬 업무 자동화 :엑셀부터 워드·PDF·이메일·웹 크롤링·파일 정리 업무까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data개발자에게 물어보세요 :디지털 공급망으로 조직의 핵심 역량 구축하기
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data이것이 자바다 :신용권의 Java 프로그래밍 정복
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data처음 배우는 인공지능 :개발자를 위한 인공지능 알고리즘과 인프라 기초
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data스프링 부트 쇼핑몰 프로젝트 with JPA
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(쉽게 배우는) 운영체제 =Introducation operating systems
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data데이터베이스 개론 =Database
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(러닝스쿨! 한 권으로 끝내는) HTML+CSS 웹 디자인 입문 :HTML, CSS 기초부터 반응형 웹 디자인, 실전 웹 사이트 제작까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(일 잘하는 직장인을 위한) 엑셀 자동화 with 파이썬 :복잡하고 지루한 반복 업무를 쉽고 빠르게 해치우는 방법
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataReal MySQL 8.0 :개발자와 DBA를 위한 MySQL 실전 가이드
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data파이브 라인스 오브 코드 :다섯 줄 제한 규칙으로 시작하는 체계적이고 효과적인 리팩터링 수련법
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data데이터 과학자의 일
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data로봇 닉키의 토끼 발견 :머신 러닝과 함께 토끼를 찾아요!
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data이것이 C#이다 :처음부터 끝까지 입문자를 배려한 C# 입문서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data게임으로 익히는 코딩 알고리즘 :취업, 이직, 승진 준비생들을 위한 알고리즘 기본 + 코딩 테스트 트레이닝 북
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data모던 자바 인 액션 :전문가를 위한 자바 8, 9, 10 기법 가이드
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data이것이 데이터 분석이다 :파이썬으로 배우는 데이터 분석 입문
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data혼자 공부하는 첫 프로그래밍 with 파이썬 :1:1 과외하듯 배우는 왕초보 코딩 입문서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(Do it!) 웹 프로그래밍을 위한 자바스크립트
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data클론 코딩 영화 평점 웹서비스 :세상의 속도를 따라잡고 싶다면 do it! =Do it! clone coding movie App Web service
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(Do it!) 클론 코딩 트위터 =노마드 코더 니꼴라스와 만드는 트위터 서비스 /Do it! clone coding Twitter
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data쿠버네티스 완벽 가이드
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(한 권으로 끝내는) 네트워크 기초 :클라우드 시대의 네트워크 입문서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data누구나 쉽게 따라 하며 배우는 웹 해킹 첫걸음 :직접 개발하고 공격·방어하는 웹 해킹 기본서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data이것이 자바다 :교육 현장에서 가장 많이 쓰이는 JAVA 프로그래밍의 기본서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data러닝 타입스크립트 :안정적인 웹 프로젝트 운영을 위한 타입스크립트의 모든 것
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataFastAPI를 사용한 파이썬 웹 개발 :라우팅 기초부터 이벤트 플래너 애플리케이션 구축 및 배포까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data컴퓨터 네트워킹 :하향식 접근
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataDo it! Node.js 프로그래밍 :실제 서버로 구동 가능한 코드로 배운다!
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data처음 읽는 양자컴퓨터 이야기 :양자컴퓨터, 그 오해와 진실 개발 최전선에서 가장 쉽게 설명한다!
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data엘라스틱 스택 =데이터 수집, 변환, 분석, 시각화를 위한 엘라스틱서치, 로그스태시, 비츠, 키바나의 모든 것 /Elastic stack
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataUX 기획의 기술 :페르소나와 시나리오 기반의 디자인 프로젝트 관리법
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataUX 개론 :글로벌 기업에서 통하는 UX 디자이너의 기본기
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataUX 디자이너로 일하고 있습니다 :현직 UXer가 들려주는 UX 디자인 커리어 가이드
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing dataData-driven UX :데이터가 두려운 실무자를 위한 입문서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data로봇 수리공 조아 씨의 코딩하기
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data로봇 강아지 딩코를 코딩하라!
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data로봇 강아지 딩코를 코딩하라!
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data인문학도, 개발자되다
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data실용 SQL :PostgreSQL로 시작하는 데이터 스토리텔링 가이드북
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(백엔드를 위한) Django REST framework with 파이썬 :MTV 패턴으로 만드는 REST API
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(후니의 쉽게 쓴) 시스코 네트워킹 :시스코 전문가가 말하는 네트워크 따라잡기
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data시크릿 코더
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(그림으로 정리한) 알고리즘과 자료구조 :자바+ 파이썬
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data아마존 웹 서비스 =AWS discovery book /Amazon web service
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data클린 코더 :단순 기술자에서 진정한 소프트웨어 장인이 되기까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data로블록스 게임 제작 점프맵 만들기 :roblox로 배우는 기초 코딩
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data데이터 과학자 :그들은 무엇을 배우고 어떻게 준비하는가?
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data사용자 경험을 창조하는 UX/UI 디자인 :NCS 기반 모바일에서 VR까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data실용주의 프로그래머
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(밑바닥부터 시작하는) 데이터 과학 :데이터 분석을 위한 파이썬 프로그래밍과 수학·통계 기초
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data웹 크롤링 & 데이터 분석 with 파이썬
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data(파이썬으로 쉽게 풀어쓴) 자료구조 =Data structures using Python
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data엔트리 코딩 탐정단
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data컴퓨터구조론 =Computer architecture
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data슈퍼인텔리전스 :경로, 위험, 전략
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data테스트 주도 개발 시작하기 =작동하는 깔끔한 코드를 만드는 데 필요한 습관 /Test-driven development
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_9_keyword_processed.xlsx:   processing data블랙 스완 :0.1%의 가능성이 모든 것을 바꾼다
# ...
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data초등 코딩 스크래치 =혼자서도 척척 /Elementary coding by scratch
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data모두의 C언어 =스스로 생각하면서 배우는 C 프로그래밍 기초 /C for everyone
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data이득우의 언리얼 C++ 게임 개발의 정석
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing dataNginx HTTP 서버 :HTTP 서버를 사용한 고성능 웹 서비스 구축
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data도커, 쿠버네티스, 테라폼으로 구현하는 마이크로서비스
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data이것이 C#이다 :처음부터 끝까지 입문자를 배려한 C# 입문서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data데이터 인문학 :세상을 움직인 역사 속 데이터 이야기
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data파이토치 첫걸음 :딥러닝 기초부터 RNN, 오토인코더, GAN 실전 기법까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(쉽게 배워 바로 써먹는) 디자인 패턴 =24가지 패턴으로 알아보는 객체지향의 원리 /Design pattern
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data이것이 C#이다 :입문자에게 가장 탄탄한 기본기를 다져줄 C# 입문서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(처음 배우는) 셸 스크립트 :시스템 구축부터 보안, 모니터링, 클라우드 운영까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data몽고DB 완벽 가이드 :실전 예제로 배우는 NoSQL 데이터베이스 기초부터 활용까지
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(완성된 웹사이트로 배우는) HTML&CSS 웹 디자인 :5개 예제로 배우는 효율적인 웹사이트 제작 노하우
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(사례 분석으로 배우는) 데이터 시각화 :막대 차트부터 대시보드까지 태블로로 실습하며 배우는 인사이트 도출법
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(Do it!) HTML5 + CSS3 웹 표준의 정석 :탄탄한 웹 기본기를 위한 교과서
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(Do it) 장고 + 부트스트랩 파이썬 웹 개발의 정석 =만들면서 배우는 웹 개발 A to Z /Do it! django + bootstrap python web programming
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(Do it!) 딥러닝 교과서 =퍼셉트론부터 GAN까지 핵심 이론 총망라! /Do it! deep learning textbook
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(Do it!) 리액트 모던 웹 개발 with 타입스크립트 =SPA와 REST API 서버 만들기! /Do it! react modern web development with TypeScript
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data(자바스크립트) 코딩의 기술 :똑똑하게 코딩하는 법
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data마인크래프트 게임 제작 무작정 따라하기 =Making Minecraft game with MakeCode
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data유니티 교과서 - 유니티(Unity) 2020 버전 완벽 대응, 개정4판
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JPA','ORM']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['JDBC']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['mvc']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :['security']
# DEBUG/content/drive/MyDrive/대출 데이터 모음/키워드 처리 폴더/2023/2023_10_keyword_processed.xlsx:   processing data     :[' HATEOAS']

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 23 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,238 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120903 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
# 한글 폰트 설정
plt.rcParams['font.family'] = 'NanumGothic'
file_path = "/content/drive/MyDrive/대출 데이터 모음/연도별 키워드 처리/spring 키워드에 대한 분석_결과.xlsx"
df = pd.read_excel(file_path, index_col="키워드")

plt.figure(figsize=(12, 8))
# vmax 값을 설정하여 범위를 조정함
sns.heatmap(df, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('연도별 키워드 대출 횟수')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
# 한글 폰트 설정
plt.rcParams['font.family'] = 'NanumGothic'
file_path = "/content/drive/MyDrive/대출 데이터 모음/연도별 키워드 처리/인프라 키워드.xlsx"

data = pd.read_excel(file_path)

# Converting the columns to a list for plotting
years = data.columns[1:].tolist()

# Plotting each keyword trend
plt.figure(figsize=(12, 6))
for index, row in data.iterrows():
    plt.plot(years, row[1:], label=row['키워드'])

plt.title('Trend of Technology Keywords (2018-2023)')
plt.xlabel('Year')
plt.ylabel('Frequency/Relevance')
plt.legend(title='Keywords', bbox_to_anchor=(1.05, 1), loc='best')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
